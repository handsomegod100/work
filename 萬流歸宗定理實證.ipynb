# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = -10*np.log(1-np.random.uniform(size =10000000))
test = plt.hist(x)

# %%
ex = plt.hist(np.random.exponential(scale = 100000, size = 10000000))
