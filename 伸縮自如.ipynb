# %%
from ipywidgets import interact

# %%
def walk(n=0):
    d = "Ｃ"+n*"二"+"３"
    print(d)

# %%
interact(walk,n=(0,40))
# Out:
# interactive(children=(IntSlider(value=0, description='n', max=40), Output()), _dom_classes=('widget-interact',…
# <function __main__.walk(n=0)>
